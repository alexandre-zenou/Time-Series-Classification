# %% [markdown]
# # Train IndPatchTSTClassifier

# %%
import importlib.util
from pathlib import Path
import sys

# Fallback: if package not installed in this kernel, add repo root to sys.path
if importlib.util.find_spec('src') is None:
    ROOT = Path('..').resolve()
    if str(ROOT) not in sys.path:
        sys.path.insert(0, str(ROOT))

# %% [markdown]
# **Prerequisite:** install the package in editable mode from the repo root:
#
# ```bash
# pip install -e .
# ```

# %%
from src.training.adapting_to_classification import (
    run_statistics,
    print_statistics,
    load_run_configs,
)

# Charge les configs YAML si elles existent (sinon valeurs par defaut)
from pathlib import Path
_cwd = Path().resolve()
if (_cwd / "configs").exists():
    PROJECT_ROOT = _cwd
elif (_cwd.parent / "configs").exists():
    PROJECT_ROOT = _cwd.parent
else:
    # Fallback: assume notebook in notebooks/
    PROJECT_ROOT = _cwd.parent
load_run_configs(config_dir=PROJECT_ROOT / "configs")

# 15 runs statistiques (seed=0..14). Peut prendre du temps.
all_results = run_statistics(n_runs=15, base_seed=0)
summary = print_statistics(all_results, baseline=0.546)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       1 from src.training.adapting_to_classification import (
#       2     run_statistics,
#       3     print_statistics,
#       4     load_run_configs,
#       5 )
#       7 # Charge les configs YAML si elles existent (sinon valeurs par defaut)
# ----> 8 load_run_configs(config_dir='configs')
#      10 # 15 runs statistiques (seed=0..14). Peut prendre du temps.
#      11 all_results = run_statistics(n_runs=15, base_seed=0)
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\training\adapting_to_classification.py:83, in load_run_configs(config_dir)
#      81 def load_run_configs(config_dir=CONFIG_DIR):
#      82     """Charge les configs Optuna depuis YAMLs (fallback sur defaults)."""
# ---> 83     backbone_cfg = _load_yaml(os.path.join(config_dir, "backbone.yml"), required=True)
#      84     scratch_cfg = _load_yaml(
#      85         os.path.join(config_dir, "scratch_backbone.yml"), DEFAULT_SCRATCH_CONFIG
#      86     )
#      87     params_head_only = _load_yaml(
#      88         os.path.join(config_dir, "params_head_only.yml"), DEFAULT_PARAMS_HEAD_ONLY
#      89     )
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\training\adapting_to_classification.py:72, in _load_yaml(path, default, required)
#      70 if not os.path.exists(path):
#      71     if required:
# ---> 72         raise FileNotFoundError(
#      73             f"Missing required config: {path}. "
#      74             "Run indpatchtst pretraining to generate configs/backbone.yml."
#      75         )
#      76     return default
#      77 with open(path, "r", encoding="utf-8") as f:
#
# FileNotFoundError: Missing required config: configs\backbone.yml. Run indpatchtst pretraining to generate configs/backbone.yml.
