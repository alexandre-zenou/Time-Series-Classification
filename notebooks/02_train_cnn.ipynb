# %% [markdown]
# # Train CNN Baseline

# %% [markdown]
# **Prerequisite:** install the package in editable mode from the repo root:
#
# ```bash
# pip install -e .
# ```

# %%
from src.models.cnn_baseline import run_statistics

# 15 runs par defaut (seed=0..14). Ajuste si besoin.
run_statistics(n_runs=15, base_seed=0)
# Out:
# === RUN 1/15 (seed=0) ===
#
# === Config 1/4: {'n_filters1': 32, 'n_filters2': 64, 'n_filters3': 128, 'n_filters4': 256, 'dropout': 0.3, 'lr': 0.001, 'weight_decay': 0.0001} ===
# Epoch 01 | Train loss: 2.0352 | Val acc: 0.3740 | Val F1: 0.1457
# Epoch 02 | Train loss: 1.7302 | Val acc: 0.3801 | Val F1: 0.1565
# Epoch 03 | Train loss: 1.5997 | Val acc: 0.3821 | Val F1: 0.1842
# Epoch 04 | Train loss: 1.5110 | Val acc: 0.3923 | Val F1: 0.1701
# Epoch 05 | Train loss: 1.4700 | Val acc: 0.4167 | Val F1: 0.2881
# Epoch 06 | Train loss: 1.4112 | Val acc: 0.4228 | Val F1: 0.2800
# Epoch 07 | Train loss: 1.3783 | Val acc: 0.3943 | Val F1: 0.2217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from src.models.cnn_baseline import run_statistics
#       3 # 15 runs par defaut (seed=0..14). Ajuste si besoin.
# ----> 4 run_statistics(n_runs=15, base_seed=0)
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\models\cnn_baseline.py:201, in run_statistics(n_runs, base_seed)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\models\cnn_baseline.py:175, in hyperparam_search(train_loader, val_loader, n_features, n_classes, device)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\models\cnn_baseline.py:93, in train_one_model(model, train_loader, val_loader, max_epochs, patience, lr, weight_decay, device)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\elyan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File c:\Users\elyan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File c:\Users\elyan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:
